# %%
import pickle as p

# %%
path = "/Users/chinu/Downloads/adarnn/PRSA_Data_1.pkl"

# %%
pickle = open ("/Users/chinu/Downloads/adarnn/PRSA_Data_1.pkl", "rb")
contents = p.load(pickle)

# %%
print(contents)
# Out:
# {'Dingling': (array([[[0.00113895, 0.00221484, 0.01743191, 0.00967528, 0.01010101,
#          0.1636417 ],
#         [0.00455581, 0.0055371 , 0.01743191, 0.00477268, 0.01010101,
#          0.15963999],
#         [0.0022779 , 0.00332226, 0.01743191, 0.00477268, 0.01010101,
#          0.15763913],
#         ...,
#         [0.00683371, 0.0055371 , 0.01743191, 0.00477268, 0.01010101,
#          0.1636417 ],
#         [0.00341686, 0.00332226, 0.01743191, 0.00477268, 0.01010101,
#          0.15763913],
#         [0.00341686, 0.00775194, 0.01743191, 0.00477268, 0.02020202,
#          0.14363313]],
#
#        [[0.00113895, 0.0055371 , 0.01743191, 0.00477268, 0.01010101,
#          0.14763485],
#         [0.00341686, 0.00442968, 0.01743191, 0.00477268, 0.01010101,
#          0.1496357 ],
#         [0.00455581, 0.        , 0.08165205, 0.18616879, 0.07070707,
#          0.07160227],
#         ...,
#         [0.05353075, 0.0730897 , 0.22935836, 0.39698049, 0.11111111,
#          0.00757485],
# ...

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from datetime import datetime, time, timedelta

# %%
df = pd.read_pickle("/Users/chinu/Downloads/adarnn/Nifty_1.pkl")

# %%
df.reset_index(drop=False, inplace=True)

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df_monthly = df.groupby(df['date'].dt.to_period('M'))
min_trading_days = df_monthly.size().min()
df_filtered = df_monthly.apply(lambda x: x.head(min_trading_days)).reset_index(drop=True)

# %%
temp_df
# Out:
#             open      high       low     close    volume        ma       rsi  \
# 0       0.348809  0.348693  0.347993  0.346261  0.001497  0.432312  0.496896
# 1       0.346585  0.345830  0.348903  0.345572  0.000440  0.432312  0.496896
# 2       0.345341  0.344610  0.348180  0.345174  0.000863  0.432312  0.496896
# 3       0.344918  0.343841  0.347028  0.343398  0.001347  0.432312  0.496896
# 4       0.343171  0.343947  0.347698  0.345280  0.000265  0.432312  0.496896
# ...          ...       ...       ...       ...       ...       ...       ...
# 673569  0.509264  0.511878  0.515574  0.511810  0.007376  0.513578  0.778112
# 673570  0.511302  0.511003  0.515789  0.509795  0.003405  0.513856  0.659419
# 673571  0.509291  0.508908  0.514664  0.509212  0.001094  0.514055  0.629734
# 673572  0.508708  0.509757  0.515199  0.510299  0.001995  0.514336  0.661570
# 673573  0.509476  0.509545  0.515976  0.510855  0.000294  0.514644  0.676800
#
# ...

# %%
temp_df = df_filtered_1.copy()
temp_df = temp_df.dropna()

# %%
len(df_filtered_1) - 14926
# Out:
# 673574

# %%
closes = temp_df['close'].values

# %%
df_filtered['year'] = df_filtered['date'].map(lambda x: pd.to_datetime(x,format='%Y-%m-%d %H:%M:%S').year)
df_filtered['day'] = df_filtered['date'].map(lambda x: pd.to_datetime(x,format='%Y-%m-%d %H:%M:%S').day)
df_filtered['month'] = df_filtered['date'].map(lambda x: pd.to_datetime(x,format='%Y-%m-%d %H:%M:%S').month)

# %%
temp = {}
for n, g in tqdm(df_filtered.groupby(by='year')):
    for n_, g_ in g.groupby(by='month'):
        for name, group in g_.groupby(by='day'):
            key = str(n)+"-"+str(n_)+"-"+str(name)
            #temp[key] = group[['open','high','low','volume','ma','rsi','vwap','21atr','bollinger_higher']].values
            temp[key] =[group[['open','high','low','volume','ma','rsi','vwap','21atr','bollinger_higher']].values, group[['close']].values]
# Out:
# 100%|███████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 26.19it/s]

# %%
df_filtered_1 = df_filtered.drop(['date','year','day','month'],axis=1)

# %%
df_filtered_1=df_filtered_1.drop('month',axis=1)

# %%
filtered_temp = {key: value for key, value in temp.items() if value.shape == (375, 9)}

# %%
counter = 0
date = []
temp2 = {}
for key in temp:
    if temp[key][0].shape==(375, 9):
        print(key, temp[key][0].shape)
        temp2[key] = temp[key]
        counter +=1
        date.append(key)
print(counter)
# Out:
# 2015-2-2 (375, 9)
# 2015-2-3 (375, 9)
# 2015-2-4 (375, 9)
# 2015-2-5 (375, 9)
# 2015-2-6 (375, 9)
# 2015-2-9 (375, 9)
# 2015-2-10 (375, 9)
# 2015-2-11 (375, 9)
# 2015-2-12 (375, 9)
# 2015-2-13 (375, 9)
# 2015-2-16 (375, 9)
# 2015-2-18 (375, 9)
# 2015-2-19 (375, 9)
# 2015-2-20 (375, 9)
# 2015-2-23 (375, 9)
# 2015-2-24 (375, 9)
# 2015-2-25 (375, 9)
# 2015-3-2 (375, 9)
# 2015-3-3 (375, 9)
# 2015-3-4 (375, 9)
# 2015-3-5 (375, 9)
# 2015-3-9 (375, 9)
# 2015-3-10 (375, 9)
# 2015-3-11 (375, 9)
# 2015-3-12 (375, 9)
# 2015-3-17 (375, 9)
# 2015-3-18 (375, 9)
# 2015-3-19 (375, 9)
# 2015-3-20 (375, 9)
# 2015-3-23 (375, 9)
# 2015-3-24 (375, 9)
# 2015-3-25 (375, 9)
# 2015-4-1 (375, 9)
# 2015-4-7 (375, 9)
# 2015-4-8 (375, 9)
# 2015-4-9 (375, 9)
# 2015-4-10 (375, 9)
# 2015-4-13 (375, 9)
# 2015-4-15 (375, 9)
# 2015-4-16 (375, 9)
# 2015-4-17 (375, 9)
# 2015-4-20 (375, 9)
# 2015-4-21 (375, 9)
# 2015-4-22 (375, 9)
# 2015-4-23 (375, 9)
# 2015-4-24 (375, 9)
# 2015-4-27 (375, 9)
# 2015-4-28 (375, 9)
# ...

# %%
len(temp2)
# Out:
# 1801

# %%
dump = list(temp2.values())
features = np.array([x[0] for x in dump])
target = np.array([x[1] for x in dump])

# %%
np.array(list(temp2.values()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[190], line 1
# ----> 1 np.array(list(temp2.values()))
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 3 dimensions. The detected shape was (1801, 2, 375) + inhomogeneous part.

# %%
features.shape
# Out:
# (1801, 375, 9)

# %%
target.shape
# Out:
# (1801, 375, 1)

# %%
trying = [features, target]

# %%
import pickle as pkl

# %%
pickle_file_path = "trying.pickle"

# Writing the list to a pickle file
with open(pickle_file_path, 'wb') as f:
    pkl.dump(trying, f)

# %%
trying[1].shape
# Out:
# (1801, 375, 1)

# %%
final_array
final_array[0] = (1801, 375, 9)

# %%
file = np.concatenate((features,target),axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 1
# ----> 1 file = np.concatenate((features,target),axis=0)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 2, the array at index 0 has size 9 and the array at index 1 has size 1

# %%
values = list(filtered_temp.values())

# %%
result = np.stack(values, axis=0)

# %%
closes.shape
# Out:
# (673574,)

# %%
result.shape
# Out:
# (1801, 375, 9)

# %%
(1801*375)
# Out:
# 675375

# %%
date_time= date

# %%
len(date_time)
# Out:
# 1801

# %%
df
# Out:
#                        date      open      high       low     close    volume  \
# 0       2015-02-02 09:15:00  0.348809  0.348693  0.347993  0.346261  0.001497
# 1       2015-02-02 09:16:00  0.346585  0.345830  0.348903  0.345572  0.000440
# 2       2015-02-02 09:17:00  0.345341  0.344610  0.348180  0.345174  0.000863
# 3       2015-02-02 09:18:00  0.344918  0.343841  0.347028  0.343398  0.001347
# 4       2015-02-02 09:19:00  0.343171  0.343947  0.347698  0.345280  0.000265
# ...                     ...       ...       ...       ...       ...       ...
# 830955  2024-01-25 15:25:00  0.830413  0.830134  0.840721  0.831403  0.001050
# 830956  2024-01-25 15:26:00  0.830413  0.882682  0.840721  0.852901  0.047643
# 830957  2024-01-25 15:27:00  0.851165  0.853810  0.849667  0.844816  0.077466
# 830958  2024-01-25 15:28:00  0.842509  0.848879  0.851648  0.847441  0.042753
# 830959  2024-01-25 15:29:00  0.847512  0.864600  0.853604  0.854386  0.065557
#
# ...

# %%
start_time = time(9, 15)
end_time = time(15, 29)
time_interval = timedelta(minutes=1)

timestamps = []

for date in date_objects:
    trading_start = datetime.combine(date, start_time)
    trading_end = datetime.combine(date, end_time)
    current_time = trading_start
    while current_time < trading_end:
        timestamps.append(current_time)
        current_time += time_interval

# %%
date_objects = []

for date_string in date_time:
    date_objects.append(datetime.strptime(date_string, '%Y-%m-%d'))

# %%
date_objects
# Out:
# [datetime.datetime(2015, 2, 2, 0, 0),
#  datetime.datetime(2015, 2, 3, 0, 0),
#  datetime.datetime(2015, 2, 4, 0, 0),
#  datetime.datetime(2015, 2, 5, 0, 0),
#  datetime.datetime(2015, 2, 6, 0, 0),
#  datetime.datetime(2015, 2, 9, 0, 0),
#  datetime.datetime(2015, 2, 10, 0, 0),
#  datetime.datetime(2015, 2, 11, 0, 0),
#  datetime.datetime(2015, 2, 12, 0, 0),
#  datetime.datetime(2015, 2, 13, 0, 0),
#  datetime.datetime(2015, 2, 16, 0, 0),
#  datetime.datetime(2015, 2, 18, 0, 0),
#  datetime.datetime(2015, 2, 19, 0, 0),
#  datetime.datetime(2015, 2, 20, 0, 0),
#  datetime.datetime(2015, 2, 23, 0, 0),
#  datetime.datetime(2015, 2, 24, 0, 0),
#  datetime.datetime(2015, 2, 25, 0, 0),
#  datetime.datetime(2015, 3, 2, 0, 0),
#  datetime.datetime(2015, 3, 3, 0, 0),
#  datetime.datetime(2015, 3, 4, 0, 0),
#  datetime.datetime(2015, 3, 5, 0, 0),
#  datetime.datetime(2015, 3, 9, 0, 0),
#  datetime.datetime(2015, 3, 10, 0, 0),
#  datetime.datetime(2015, 3, 11, 0, 0),
# ...

# %%
timestamps
# Out:
# [datetime.datetime(2015, 2, 2, 9, 15),
#  datetime.datetime(2015, 2, 2, 9, 16),
#  datetime.datetime(2015, 2, 2, 9, 17),
#  datetime.datetime(2015, 2, 2, 9, 18),
#  datetime.datetime(2015, 2, 2, 9, 19),
#  datetime.datetime(2015, 2, 2, 9, 20),
#  datetime.datetime(2015, 2, 2, 9, 21),
#  datetime.datetime(2015, 2, 2, 9, 22),
#  datetime.datetime(2015, 2, 2, 9, 23),
#  datetime.datetime(2015, 2, 2, 9, 24),
#  datetime.datetime(2015, 2, 2, 9, 25),
#  datetime.datetime(2015, 2, 2, 9, 26),
#  datetime.datetime(2015, 2, 2, 9, 27),
#  datetime.datetime(2015, 2, 2, 9, 28),
#  datetime.datetime(2015, 2, 2, 9, 29),
#  datetime.datetime(2015, 2, 2, 9, 30),
#  datetime.datetime(2015, 2, 2, 9, 31),
#  datetime.datetime(2015, 2, 2, 9, 32),
#  datetime.datetime(2015, 2, 2, 9, 33),
#  datetime.datetime(2015, 2, 2, 9, 34),
#  datetime.datetime(2015, 2, 2, 9, 35),
#  datetime.datetime(2015, 2, 2, 9, 36),
#  datetime.datetime(2015, 2, 2, 9, 37),
#  datetime.datetime(2015, 2, 2, 9, 38),
# ...

# %%
df_filtered_1['Date'] = pd.DataFrame(timestamps, columns=['DateTime'])

# %%
df_filtered_1 = df_filtered_1.set_index('Date', inplace=True)

# %%
df_filtered_1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[206], line 1
# ----> 1 df_filtered_1.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
